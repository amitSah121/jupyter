# %% [markdown]
# ## Datasets

# %%
import torch
from torch import nn

# %% [markdown]
# # Getting dataset

# %%
import requests
import zipfile
from pathlib import Path

# %%
data_path = Path("temp/")
data_path = data_path / "data"
image_data_path = data_path / "pizza_steak_sushi"

if image_data_path.is_dir():
    print(f"{image_data_path} already exists skipping download")
else:
    print("Making dir")
    image_data_path.mkdir(parents=True, exist_ok=True)
# Out:
# temp/data/pizza_steak_sushi already exists skipping download

# %%
with open(data_path / "pizza_steak_sushi.zip", "wb") as f:
    request = requests.get("https://github.com/mrdbourke/pytorch-deep-learning/raw/main/data/pizza_steak_sushi.zip")
    print("Downloading pizza, steak, sushi data...")
    f.write(request.content)

# Unzip pizza, steak, sushi data
with zipfile.ZipFile(data_path / "pizza_steak_sushi.zip", "r") as zip_ref:
    print("Unzipping pizza, steak, sushi data...") 
    zip_ref.extractall(image_data_path)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~/vs_code/jupyter/env/lib/python3.11/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# ...

# %%
import os

def walk_through():
    for dirpath, dirnames, filenames in os.walk(image_data_path):
        print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
walk_through()
# Out:
# There are 2 directories and 0 images in 'temp/data/pizza_steak_sushi'.
# There are 3 directories and 0 images in 'temp/data/pizza_steak_sushi/test'.
# There are 0 directories and 25 images in 'temp/data/pizza_steak_sushi/test/pizza'.
# There are 0 directories and 19 images in 'temp/data/pizza_steak_sushi/test/steak'.
# There are 0 directories and 31 images in 'temp/data/pizza_steak_sushi/test/sushi'.
# There are 3 directories and 0 images in 'temp/data/pizza_steak_sushi/train'.
# There are 0 directories and 78 images in 'temp/data/pizza_steak_sushi/train/pizza'.
# There are 0 directories and 75 images in 'temp/data/pizza_steak_sushi/train/steak'.
# There are 0 directories and 72 images in 'temp/data/pizza_steak_sushi/train/sushi'.

# %%
import random
from PIL import Image

# %%
random.seed(42)

images = list(image_data_path.glob("*/*/*.jpg"))
random_image_path = random.choice(images)

image_class = random_image_path.parent.stem

# 4. Open image
img = Image.open(random_image_path)

# 5. Print metadata
print(f"Random image path: {random_image_path}")
print(f"Image class: {image_class}")
print(f"Image height: {img.height}") 
print(f"Image width: {img.width}")
img
# Out:
# Random image path: temp/data/pizza_steak_sushi/test/sushi/1742201.jpg
# Image class: sushi
# Image height: 512
# Image width: 512
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %% [markdown]
# ## Transforming Data

# %%
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %%
data_transform = transforms.Compose([
    transforms.Resize(size=(64,64)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor()
])

# %%
data_transform(img).shape
# Out:
# torch.Size([3, 64, 64])

# %%
import matplotlib.pyplot as plt

def plot_transformed(image_list, transform, n=3, seed=42):
    random.seed(seed)

    random_img = random.sample(images,k=n)

    for img in random_img:
        with Image.open(img) as f:
            fig, ax = plt.subplots(1,2)
            ax[0].imshow(f) 
            ax[0].set_title(f"Original \nSize: {f.size}")
            ax[0].axis("off")

            transformed = transform(f).permute(1,2,0)
            ax[1].imshow(transformed)
            ax[1].set_title(f"Transformed \nSize: {transformed.shape}")
            ax[1].axis("off")

            fig.suptitle(f"Class: {img.parent.stem}", fontsize=16)

plot_transformed(images,transform=data_transform, n=3)

# %%
# Setup train and testing paths
train_dir = image_data_path / "train"
test_dir = image_data_path / "test"

train_dir, test_dir
# Out:
# (PosixPath('temp/data/pizza_steak_sushi/train'),
#  PosixPath('temp/data/pizza_steak_sushi/test'))

# %%
from torchvision import datasets

train_data = datasets.ImageFolder(root=train_dir,
                                 transform=data_transform,
                                 target_transform=None)
test_data = datasets.ImageFolder(root=test_dir,
                                 transform=data_transform)

train_data, test_data
# Out:
# (Dataset ImageFolder
#      Number of datapoints: 225
#      Root location: temp/data/pizza_steak_sushi/train
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=(64, 64), interpolation=bilinear, max_size=None, antialias=True)
#                 RandomHorizontalFlip(p=0.5)
#                 ToTensor()
#             ),
#  Dataset ImageFolder
#      Number of datapoints: 75
#      Root location: temp/data/pizza_steak_sushi/test
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=(64, 64), interpolation=bilinear, max_size=None, antialias=True)
#                 RandomHorizontalFlip(p=0.5)
#                 ToTensor()
#             ))

# %%
from torch.utils.data import DataLoader

train_dataloader = DataLoader(dataset=train_data,
                             batch_size=1,
                             num_workers=1,
                             shuffle=True)


test_dataloader = DataLoader(dataset=test_data,
                             batch_size=1,
                             num_workers=1,
                             shuffle=True)

# %%
len(train_dataloader), len(test_dataloader)
# Out:
# (225, 75)

# %%
len(train_dataloader.dataset),len(train_dataloader.dataset[0]),len(train_dataloader.dataset[0][0]),len(train_dataloader.dataset[0][0][0]),len(train_dataloader.dataset[0][0][0][0])
# Out:
# (225, 2, 3, 64, 64)

# %%
len(train_dataloader.dataset),len(train_dataloader.dataset[0]),train_dataloader.dataset[100][1]
# Out:
# (225, 2, 1)

# %% [markdown]
# ## create our own dataset loader class

# %%
import os
import pathlib
import torch

from PIL import Image
from torch.utils.data import Dataset
from torchvision import transforms
from typing import Tuple, Dict, List

# %%
class_names = [entry.name for entry in list(os.scandir("./temp/data/pizza_steak_sushi/train"))]
class_names
# Out:
# ['pizza', 'steak', 'sushi']

# %%
def find_classes(dir: str) -> Tuple[List[str], Dict[str,int]] :
    classes = sorted([entry.name for entry in list(os.scandir(dir)) if entry.is_dir()])

    if not classes:
        print("Couldn't find any classes in target directory")
        return None
    class_idx = {class_name: i for i,class_name in enumerate(classes)}
    return classes, class_idx

# %%
class_names = find_classes("./temp/data/pizza_steak_sushi/train")
class_names
# Out:
# (['pizza', 'steak', 'sushi'], {'pizza': 0, 'steak': 1, 'sushi': 2})

# %%
class ImageFolderCustom(Dataset):
    def __init__(self, target_dir: str, transform: None):
        self.paths = pathlib.Path(target_dir).glob("*/*.jpg")
        self.transform = transform
        self.classes, self.class_idx = find_classes(target_dir)

    def loadImage(self, index):
        img = self.paths[index]
        return Image.open(img)

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, index) -> Tuple[torch.Tensor, int]:
        img = self.loadImage(index)
        class_name = self.paths[index].parent.name
        class_idx = self.class_idx[class_name]

        if self.transform:
            return self.transform(img), class_idx
        else:
            return img, class_idx

# %%
train_img_custom = ImageFolderCustom("./temp/data/pizza_steak_sushi/train", transform= data_transform)
test_img_custom = ImageFolderCustom("./temp/data/pizza_steak_sushi/test", transform= data_transform)

# %%
def display_random_images(dataset: torch.utils.data.dataset.Dataset,
                          classes: List[str] = None,
                          n: int = 10,
                          display_shape: bool = True,
                          seed: int = None):
    
    # 2. Adjust display if n too high
    if n > 10:
        n = 10
        display_shape = False
        print(f"For display purposes, n shouldn't be larger than 10, setting to 10 and removing shape display.")
    
    # 3. Set random seed
    if seed:
        random.seed(seed)

    # 4. Get random sample indexes
    random_samples_idx = random.sample(range(len(dataset)), k=n)

    # 5. Setup plot
    plt.figure(figsize=(16, 8))

    # 6. Loop through samples and display random samples 
    for i, targ_sample in enumerate(random_samples_idx):
        targ_image, targ_label = dataset[targ_sample][0], dataset[targ_sample][1]

        # 7. Adjust image tensor shape for plotting: [color_channels, height, width] -> [color_channels, height, width]
        targ_image_adjust = targ_image.permute(1, 2, 0)

        # Plot adjusted samples
        plt.subplot(1, n, i+1)
        plt.imshow(targ_image_adjust)
        plt.axis("off")
        if classes:
            title = f"class: {classes[targ_label]}"
            if display_shape:
                title = title + f"\nshape: {targ_image_adjust.shape}"
        plt.title(title)

# %%
display_random_images(train_data, 
                      n=5, 
                      classes=class_names,
                      seed=None)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 display_random_images(train_data,
#       2                       n=5,
#       3                       classes=class_names,
#       4                       seed=None)
#
# Cell In[53], line 35, in display_random_images(dataset, classes, n, display_shape, seed)
#      33 plt.axis("off")
#      34 if classes:
# ---> 35     title = f"class: {classes[targ_label]}"
#      36     if display_shape:
#      37         title = title + f"\nshape: {targ_image_adjust.shape}"
#
# IndexError: tuple index out of range
