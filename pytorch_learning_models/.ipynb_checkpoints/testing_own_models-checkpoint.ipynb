# %% [markdown]
# ## Using cattle breed dataset from kaggle
#
# This Cattle Breeds Dataset consists of 5 different breeds [Ayrshire, Brown Swiss, Holstein Friesian, Jersey, Red Dane].

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import requests
import zipfile
from pathlib import Path

import os
import random
from PIL import Image

# %%
image_data_path = Path("./data/archive/Cattle Breeds")

def walk_through(image_data_path):
    image_dirs = []
    for dirpath, dirnames, filenames in os.walk(image_data_path):
        print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
        temp = Path(dirpath)
        image_dirs.append(temp)
    return image_dirs
    
image_dirs = walk_through(image_data_path)
image_dirs.pop(0)
# Out:
# There are 5 directories and 0 images in 'data/archive/Cattle Breeds'.
# There are 0 directories and 260 images in 'data/archive/Cattle Breeds/Ayrshire cattle'.
# There are 0 directories and 238 images in 'data/archive/Cattle Breeds/Brown Swiss cattle'.
# There are 0 directories and 254 images in 'data/archive/Cattle Breeds/Holstein Friesian cattle'.
# There are 0 directories and 252 images in 'data/archive/Cattle Breeds/Jersey cattle'.
# There are 0 directories and 204 images in 'data/archive/Cattle Breeds/Red Dane cattle'.
# PosixPath('data/archive/Cattle Breeds')

# %%
image_dirs
# Out:
# [PosixPath('data/archive/Cattle Breeds/Ayrshire cattle'),
#  PosixPath('data/archive/Cattle Breeds/Brown Swiss cattle'),
#  PosixPath('data/archive/Cattle Breeds/Holstein Friesian cattle'),
#  PosixPath('data/archive/Cattle Breeds/Jersey cattle'),
#  PosixPath('data/archive/Cattle Breeds/Red Dane cattle')]

# %%
image_dirs[0].name
list(image_dirs[0].glob("*.jpg"))
# Out:
# [PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle0.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle0_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle1.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle10.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle100.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle100_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle101.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle101_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle102.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle102_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle103.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle103_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle104.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle104_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle105.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle105_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle106.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle106_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle107.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle107_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle109.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle109_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle10_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle11.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle111.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle111_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle113.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle113_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle116.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle116_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle117.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle117_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle118.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle118_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle119.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle119_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle11_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle12.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle121.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle121_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle122.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle122_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle123.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle123_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle124.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle124_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle125.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle125_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle126.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle126_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle127.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle127_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle128.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle128_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle12_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle130.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle130_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle132.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle132_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle133.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle133_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle134.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle134_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle135.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle135_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle136.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle136_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle137.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle137_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle138.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle138_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle139.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle139_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle14.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle141.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle141_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle142.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle142_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle144.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle144_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle145.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle145_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle146.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle146_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle147.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle147_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle148.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle148_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle149.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle149_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle14_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle15.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle15_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle16.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle16_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle17.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle17_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle18.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle18_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle19.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle19_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle1_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle2.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle20.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle20_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle22.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle22_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle24.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle24_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle25.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle25_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle26.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle26_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle27.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle27_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle28.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle28_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle29.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle29_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle2_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle3.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle30.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle30_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle31.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle31_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle32.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle32_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle33.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle33_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle34.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle34_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle35.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle35_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle36.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle36_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle38.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle38_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle39.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle39_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle3_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle4.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle40.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle40_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle41.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle41_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle42.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle42_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle43.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle43_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle44.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle44_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle45.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle45_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle46.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle46_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle47.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle47_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle49.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle49_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle4_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle5.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle50.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle50_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle51.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle51_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle52.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle52_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle53.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle53_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle54.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle54_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle55.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle55_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle56.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle56_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle57.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle57_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle58.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle58_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle59.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle59_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle5_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle6.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle60.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle60_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle62.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle62_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle63.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle63_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle64.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle64_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle65.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle65_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle66.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle66_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle67.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle67_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle68.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle68_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle69.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle69_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle6_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle7.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle70.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle70_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle71.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle71_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle72.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle72_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle74.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle74_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle75.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle75_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle76.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle76_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle77.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle77_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle78.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle78_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle79.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle79_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle7_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle8.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle80.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle80_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle81.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle81_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle82.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle82_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle83.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle83_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle84.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle84_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle85.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle85_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle86.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle86_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle87.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle87_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle88.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle88_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle89.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle89_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle8_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle9.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle90.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle90_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle92.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle92_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle94.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle94_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle95.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle95_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle97.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle97_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle98.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle98_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle99.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle99_c.jpg'),
#  PosixPath('data/archive/Cattle Breeds/Ayrshire cattle/Ayrshirecattle9_c.jpg')]

# %%
# len(image_dirs)

# %%
images , label = [] , []

for path in image_dirs:
    image_paths = list(path.glob("*.jpg"))
    for image_path in image_paths:
        images.append(Image.open(image_path))
        label.append(path.name)

# %%
len(images)
# Out:
# 1208

# %%
random.randint(1,255)
# Out:
# 57

# %%
rows, cols = 1,2
for i in range(10):
    fig, axes = plt.subplots(rows,cols)
    a1 = int(random.randint(1,len(images)))
    a2 = int(random.randint(1,len(images)))
    axes[0].imshow(images[a1])
    axes[0].set_title(label[a1])
    axes[1].imshow(images[a2])
    axes[1].set_title(label[a2])
# plt.title(label[0])
# plt.show()

# %%
import torch
import torch.nn as nn
from torchvision.transforms import v2
from torch.utils.data import DataLoader
from typing import Tuple, Dict, List 
from torch.utils.data import Dataset
# from torchinfo import summary
# from torch.utils.tensorboard import SummaryWriter
from collections import OrderedDict

# %%
images[0]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300>

# %%
H, W = 32, 32
# img = torch.randint(0, 256, size=(3, H, W), dtype=torch.uint8)
img = images[0]

transforms = v2.Compose([
    v2.Resize(size=(64,64)),
    v2.PILToTensor(),
])
img = transforms(img)
# plt.imshow(img[0]+img[1]+img[2])
img.shape
# Out:
# torch.Size([3, 64, 64])

# %%
plt.imshow(img.permute((1,2,0)))

# %%
train_dataloader = DataLoader(dataset=images,
                             batch_size=1,
                             num_workers=1,
                             shuffle=True)
train_dataloader

# test_dataloader = DataLoader(dataset=test_data,
#                              batch_size=1,
#                              num_workers=1,
#                              shuffle=True)

# %%
def find_classes(dir: str) -> Tuple[List[str], Dict[str,int]] :
    classes = sorted([entry.name for entry in list(os.scandir(dir)) if entry.is_dir()])

    if not classes:
        print("Couldn't find any classes in target directory")
        return None
    class_idx = {class_name: i for i,class_name in enumerate(classes)}
    return classes, class_idx

# %%
find_classes(image_data_path)
# Out:
# (['Ayrshire cattle',
#   'Brown Swiss cattle',
#   'Holstein Friesian cattle',
#   'Jersey cattle',
#   'Red Dane cattle'],
#  {'Ayrshire cattle': 0,
#   'Brown Swiss cattle': 1,
#   'Holstein Friesian cattle': 2,
#   'Jersey cattle': 3,
#   'Red Dane cattle': 4})

# %%
(image_data_path / list(os.scandir(image_data_path))[0]).glob("*.jpg")
# Out:
# <generator object Path.glob at 0x7f0b926ce240>

# %%
class ImageFolderCustom(Dataset):
    def __init__(self, target_dir: str, transform: None):
        self.classes = []
        self.class_idx = {}
        self.paths = []
        self.p,self.q = find_classes(target_dir)
        for path in image_dirs:
            image_paths = list(path.glob("*.jpg"))
            for image_path in image_paths:
                self.paths.append(image_path)
                self.classes.append(image_path.name)
                self.class_idx[image_path.name] = self.q[path.name]
        # self.classes, self.class_idx = find_classes(target_dir)
        self.transform = transform

    def loadImage(self, index):
        img = self.paths[index]
        return Image.open(img)

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, index) -> Tuple[torch.Tensor, int]:
        img = self.loadImage(index)
        class_name = self.paths[index].name
        class_idx = self.class_idx[class_name]

        if self.transform:
            return self.transform(img), class_idx
        else:
            return img, class_idx

# %%
data_transform = v2.Compose([
    v2.Resize(size=(128,128)),
    v2.ToTensor()
])
# Out:
# /home/groupe/vs_code/jupyter/env/lib/python3.11/site-packages/torchvision/transforms/v2/_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(

# %%
img_custom = ImageFolderCustom(image_data_path, transform= data_transform)
# test_img_custom = ImageFolderCustom("./temp/data/pizza_steak_sushi/test", transform= data_transform)
len(img_custom.paths)
# Out:
# 1208

# %%
img_custom_dataloader = DataLoader(img_custom, batch_size=64)
img_custom_dataloader

# %%
train_features, train_labels = next(iter(img_custom_dataloader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
img = train_features[0].squeeze()
label = train_labels[0]
plt.imshow(img.permute(1,2,0), cmap="gray")
plt.show()
print(f"Label: {label}")
# Out:
# Feature batch shape: torch.Size([64, 3, 128, 128])
# Labels batch shape: torch.Size([64])
# Label: 0

# %%
train_size = int(0.8 * len(img_custom))
test_size = len(img_custom) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(img_custom, [train_size, test_size])

# %%
train_size, test_size
# Out:
# (966, 242)

# %%
train_dataloader = DataLoader(train_dataset, batch_size=64)
test_dataloader = DataLoader(test_dataset, batch_size=64)

# %%
train_features, train_labels = next(iter(train_dataloader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
img = train_features[0].squeeze()
label = train_labels[0]
plt.imshow(img.permute(1,2,0), cmap="gray")
plt.show()
print(f"Label: {label}")
# Out:
# Feature batch shape: torch.Size([64, 3, 128, 128])
# Labels batch shape: torch.Size([64])
# Label: 3

# %%
img_custom.classes
# Out:
# ['Ayrshirecattle0.jpg',
#  'Ayrshirecattle0_c.jpg',
#  'Ayrshirecattle1.jpg',
#  'Ayrshirecattle10.jpg',
#  'Ayrshirecattle100.jpg',
#  'Ayrshirecattle100_c.jpg',
#  'Ayrshirecattle101.jpg',
#  'Ayrshirecattle101_c.jpg',
#  'Ayrshirecattle102.jpg',
#  'Ayrshirecattle102_c.jpg',
#  'Ayrshirecattle103.jpg',
#  'Ayrshirecattle103_c.jpg',
#  'Ayrshirecattle104.jpg',
#  'Ayrshirecattle104_c.jpg',
#  'Ayrshirecattle105.jpg',
#  'Ayrshirecattle105_c.jpg',
#  'Ayrshirecattle106.jpg',
#  'Ayrshirecattle106_c.jpg',
#  'Ayrshirecattle107.jpg',
#  'Ayrshirecattle107_c.jpg',
#  'Ayrshirecattle109.jpg',
#  'Ayrshirecattle109_c.jpg',
#  'Ayrshirecattle10_c.jpg',
#  'Ayrshirecattle11.jpg',
#  'Ayrshirecattle111.jpg',
#  'Ayrshirecattle111_c.jpg',
#  'Ayrshirecattle113.jpg',
#  'Ayrshirecattle113_c.jpg',
#  'Ayrshirecattle116.jpg',
#  'Ayrshirecattle116_c.jpg',
#  'Ayrshirecattle117.jpg',
#  'Ayrshirecattle117_c.jpg',
#  'Ayrshirecattle118.jpg',
#  'Ayrshirecattle118_c.jpg',
#  'Ayrshirecattle119.jpg',
#  'Ayrshirecattle119_c.jpg',
#  'Ayrshirecattle11_c.jpg',
#  'Ayrshirecattle12.jpg',
#  'Ayrshirecattle121.jpg',
#  'Ayrshirecattle121_c.jpg',
#  'Ayrshirecattle122.jpg',
#  'Ayrshirecattle122_c.jpg',
#  'Ayrshirecattle123.jpg',
#  'Ayrshirecattle123_c.jpg',
#  'Ayrshirecattle124.jpg',
#  'Ayrshirecattle124_c.jpg',
#  'Ayrshirecattle125.jpg',
#  'Ayrshirecattle125_c.jpg',
#  'Ayrshirecattle126.jpg',
#  'Ayrshirecattle126_c.jpg',
#  'Ayrshirecattle127.jpg',
#  'Ayrshirecattle127_c.jpg',
#  'Ayrshirecattle128.jpg',
#  'Ayrshirecattle128_c.jpg',
#  'Ayrshirecattle12_c.jpg',
#  'Ayrshirecattle130.jpg',
#  'Ayrshirecattle130_c.jpg',
#  'Ayrshirecattle132.jpg',
#  'Ayrshirecattle132_c.jpg',
#  'Ayrshirecattle133.jpg',
#  'Ayrshirecattle133_c.jpg',
#  'Ayrshirecattle134.jpg',
#  'Ayrshirecattle134_c.jpg',
#  'Ayrshirecattle135.jpg',
#  'Ayrshirecattle135_c.jpg',
#  'Ayrshirecattle136.jpg',
#  'Ayrshirecattle136_c.jpg',
#  'Ayrshirecattle137.jpg',
#  'Ayrshirecattle137_c.jpg',
#  'Ayrshirecattle138.jpg',
#  'Ayrshirecattle138_c.jpg',
#  'Ayrshirecattle139.jpg',
#  'Ayrshirecattle139_c.jpg',
#  'Ayrshirecattle14.jpg',
#  'Ayrshirecattle141.jpg',
#  'Ayrshirecattle141_c.jpg',
#  'Ayrshirecattle142.jpg',
#  'Ayrshirecattle142_c.jpg',
#  'Ayrshirecattle144.jpg',
#  'Ayrshirecattle144_c.jpg',
#  'Ayrshirecattle145.jpg',
#  'Ayrshirecattle145_c.jpg',
#  'Ayrshirecattle146.jpg',
#  'Ayrshirecattle146_c.jpg',
#  'Ayrshirecattle147.jpg',
#  'Ayrshirecattle147_c.jpg',
#  'Ayrshirecattle148.jpg',
#  'Ayrshirecattle148_c.jpg',
#  'Ayrshirecattle149.jpg',
#  'Ayrshirecattle149_c.jpg',
#  'Ayrshirecattle14_c.jpg',
#  'Ayrshirecattle15.jpg',
#  'Ayrshirecattle15_c.jpg',
#  'Ayrshirecattle16.jpg',
#  'Ayrshirecattle16_c.jpg',
#  'Ayrshirecattle17.jpg',
#  'Ayrshirecattle17_c.jpg',
#  'Ayrshirecattle18.jpg',
#  'Ayrshirecattle18_c.jpg',
#  'Ayrshirecattle19.jpg',
#  'Ayrshirecattle19_c.jpg',
#  'Ayrshirecattle1_c.jpg',
#  'Ayrshirecattle2.jpg',
#  'Ayrshirecattle20.jpg',
#  'Ayrshirecattle20_c.jpg',
#  'Ayrshirecattle22.jpg',
#  'Ayrshirecattle22_c.jpg',
#  'Ayrshirecattle24.jpg',
#  'Ayrshirecattle24_c.jpg',
#  'Ayrshirecattle25.jpg',
#  'Ayrshirecattle25_c.jpg',
#  'Ayrshirecattle26.jpg',
#  'Ayrshirecattle26_c.jpg',
#  'Ayrshirecattle27.jpg',
#  'Ayrshirecattle27_c.jpg',
#  'Ayrshirecattle28.jpg',
#  'Ayrshirecattle28_c.jpg',
#  'Ayrshirecattle29.jpg',
#  'Ayrshirecattle29_c.jpg',
#  'Ayrshirecattle2_c.jpg',
#  'Ayrshirecattle3.jpg',
#  'Ayrshirecattle30.jpg',
#  'Ayrshirecattle30_c.jpg',
#  'Ayrshirecattle31.jpg',
#  'Ayrshirecattle31_c.jpg',
#  'Ayrshirecattle32.jpg',
#  'Ayrshirecattle32_c.jpg',
#  'Ayrshirecattle33.jpg',
#  'Ayrshirecattle33_c.jpg',
#  'Ayrshirecattle34.jpg',
#  'Ayrshirecattle34_c.jpg',
#  'Ayrshirecattle35.jpg',
#  'Ayrshirecattle35_c.jpg',
#  'Ayrshirecattle36.jpg',
#  'Ayrshirecattle36_c.jpg',
#  'Ayrshirecattle38.jpg',
#  'Ayrshirecattle38_c.jpg',
#  'Ayrshirecattle39.jpg',
#  'Ayrshirecattle39_c.jpg',
#  'Ayrshirecattle3_c.jpg',
#  'Ayrshirecattle4.jpg',
#  'Ayrshirecattle40.jpg',
#  'Ayrshirecattle40_c.jpg',
#  'Ayrshirecattle41.jpg',
#  'Ayrshirecattle41_c.jpg',
#  'Ayrshirecattle42.jpg',
#  'Ayrshirecattle42_c.jpg',
#  'Ayrshirecattle43.jpg',
#  'Ayrshirecattle43_c.jpg',
#  'Ayrshirecattle44.jpg',
#  'Ayrshirecattle44_c.jpg',
#  'Ayrshirecattle45.jpg',
#  'Ayrshirecattle45_c.jpg',
#  'Ayrshirecattle46.jpg',
#  'Ayrshirecattle46_c.jpg',
#  'Ayrshirecattle47.jpg',
#  'Ayrshirecattle47_c.jpg',
#  'Ayrshirecattle49.jpg',
#  'Ayrshirecattle49_c.jpg',
#  'Ayrshirecattle4_c.jpg',
#  'Ayrshirecattle5.jpg',
#  'Ayrshirecattle50.jpg',
#  'Ayrshirecattle50_c.jpg',
#  'Ayrshirecattle51.jpg',
#  'Ayrshirecattle51_c.jpg',
#  'Ayrshirecattle52.jpg',
#  'Ayrshirecattle52_c.jpg',
#  'Ayrshirecattle53.jpg',
#  'Ayrshirecattle53_c.jpg',
#  'Ayrshirecattle54.jpg',
#  'Ayrshirecattle54_c.jpg',
#  'Ayrshirecattle55.jpg',
#  'Ayrshirecattle55_c.jpg',
#  'Ayrshirecattle56.jpg',
#  'Ayrshirecattle56_c.jpg',
#  'Ayrshirecattle57.jpg',
#  'Ayrshirecattle57_c.jpg',
#  'Ayrshirecattle58.jpg',
#  'Ayrshirecattle58_c.jpg',
#  'Ayrshirecattle59.jpg',
#  'Ayrshirecattle59_c.jpg',
#  'Ayrshirecattle5_c.jpg',
#  'Ayrshirecattle6.jpg',
#  'Ayrshirecattle60.jpg',
#  'Ayrshirecattle60_c.jpg',
#  'Ayrshirecattle62.jpg',
#  'Ayrshirecattle62_c.jpg',
#  'Ayrshirecattle63.jpg',
#  'Ayrshirecattle63_c.jpg',
#  'Ayrshirecattle64.jpg',
#  'Ayrshirecattle64_c.jpg',
#  'Ayrshirecattle65.jpg',
#  'Ayrshirecattle65_c.jpg',
#  'Ayrshirecattle66.jpg',
#  'Ayrshirecattle66_c.jpg',
#  'Ayrshirecattle67.jpg',
#  'Ayrshirecattle67_c.jpg',
#  'Ayrshirecattle68.jpg',
#  'Ayrshirecattle68_c.jpg',
#  'Ayrshirecattle69.jpg',
#  'Ayrshirecattle69_c.jpg',
#  'Ayrshirecattle6_c.jpg',
#  'Ayrshirecattle7.jpg',
#  'Ayrshirecattle70.jpg',
#  'Ayrshirecattle70_c.jpg',
#  'Ayrshirecattle71.jpg',
#  'Ayrshirecattle71_c.jpg',
#  'Ayrshirecattle72.jpg',
#  'Ayrshirecattle72_c.jpg',
#  'Ayrshirecattle74.jpg',
#  'Ayrshirecattle74_c.jpg',
#  'Ayrshirecattle75.jpg',
#  'Ayrshirecattle75_c.jpg',
#  'Ayrshirecattle76.jpg',
#  'Ayrshirecattle76_c.jpg',
#  'Ayrshirecattle77.jpg',
#  'Ayrshirecattle77_c.jpg',
#  'Ayrshirecattle78.jpg',
#  'Ayrshirecattle78_c.jpg',
#  'Ayrshirecattle79.jpg',
#  'Ayrshirecattle79_c.jpg',
#  'Ayrshirecattle7_c.jpg',
#  'Ayrshirecattle8.jpg',
#  'Ayrshirecattle80.jpg',
#  'Ayrshirecattle80_c.jpg',
#  'Ayrshirecattle81.jpg',
#  'Ayrshirecattle81_c.jpg',
#  'Ayrshirecattle82.jpg',
#  'Ayrshirecattle82_c.jpg',
#  'Ayrshirecattle83.jpg',
#  'Ayrshirecattle83_c.jpg',
#  'Ayrshirecattle84.jpg',
#  'Ayrshirecattle84_c.jpg',
#  'Ayrshirecattle85.jpg',
#  'Ayrshirecattle85_c.jpg',
#  'Ayrshirecattle86.jpg',
#  'Ayrshirecattle86_c.jpg',
#  'Ayrshirecattle87.jpg',
#  'Ayrshirecattle87_c.jpg',
#  'Ayrshirecattle88.jpg',
#  'Ayrshirecattle88_c.jpg',
#  'Ayrshirecattle89.jpg',
#  'Ayrshirecattle89_c.jpg',
#  'Ayrshirecattle8_c.jpg',
#  'Ayrshirecattle9.jpg',
#  'Ayrshirecattle90.jpg',
#  'Ayrshirecattle90_c.jpg',
#  'Ayrshirecattle92.jpg',
#  'Ayrshirecattle92_c.jpg',
#  'Ayrshirecattle94.jpg',
#  'Ayrshirecattle94_c.jpg',
#  'Ayrshirecattle95.jpg',
#  'Ayrshirecattle95_c.jpg',
#  'Ayrshirecattle97.jpg',
#  'Ayrshirecattle97_c.jpg',
#  'Ayrshirecattle98.jpg',
#  'Ayrshirecattle98_c.jpg',
#  'Ayrshirecattle99.jpg',
#  'Ayrshirecattle99_c.jpg',
#  'Ayrshirecattle9_c.jpg',
#  'BrownSwisscattle0.jpg',
#  'BrownSwisscattle0_c.jpg',
#  'BrownSwisscattle1.jpg',
#  'BrownSwisscattle100.jpg',
#  'BrownSwisscattle100_c.jpg',
#  'BrownSwisscattle101.jpg',
#  'BrownSwisscattle101_c.jpg',
#  'BrownSwisscattle103.jpg',
#  'BrownSwisscattle103_c.jpg',
#  'BrownSwisscattle104.jpg',
#  'BrownSwisscattle104_c.jpg',
#  'BrownSwisscattle105.jpg',
#  'BrownSwisscattle105_c.jpg',
#  'BrownSwisscattle106.jpg',
#  'BrownSwisscattle106_c.jpg',
#  'BrownSwisscattle107.jpg',
#  'BrownSwisscattle107_c.jpg',
#  'BrownSwisscattle108.jpg',
#  'BrownSwisscattle108_c.jpg',
#  'BrownSwisscattle109.jpg',
#  'BrownSwisscattle109_c.jpg',
#  'BrownSwisscattle11.jpg',
#  'BrownSwisscattle111.jpg',
#  'BrownSwisscattle111_c.jpg',
#  'BrownSwisscattle112.jpg',
#  'BrownSwisscattle112_c.jpg',
#  'BrownSwisscattle113.jpg',
#  'BrownSwisscattle113_c.jpg',
#  'BrownSwisscattle114.jpg',
#  'BrownSwisscattle114_c.jpg',
#  'BrownSwisscattle115.jpg',
#  'BrownSwisscattle115_c.jpg',
#  'BrownSwisscattle117.jpg',
#  'BrownSwisscattle117_c.jpg',
#  'BrownSwisscattle118.jpg',
#  'BrownSwisscattle118_c.jpg',
#  'BrownSwisscattle11_c.jpg',
#  'BrownSwisscattle12.jpg',
#  'BrownSwisscattle120.jpg',
#  'BrownSwisscattle120_c.jpg',
#  'BrownSwisscattle121.jpg',
#  'BrownSwisscattle121_c.jpg',
#  'BrownSwisscattle123.jpg',
#  'BrownSwisscattle123_c.jpg',
#  'BrownSwisscattle124.jpg',
#  'BrownSwisscattle124_c.jpg',
#  'BrownSwisscattle125.jpg',
#  'BrownSwisscattle125_c.jpg',
#  'BrownSwisscattle126.jpg',
#  'BrownSwisscattle126_c.jpg',
#  'BrownSwisscattle127.jpg',
#  'BrownSwisscattle127_c.jpg',
#  'BrownSwisscattle128.jpg',
#  'BrownSwisscattle128_c.jpg',
#  'BrownSwisscattle129.jpg',
#  'BrownSwisscattle129_c.jpg',
#  'BrownSwisscattle12_c.jpg',
#  'BrownSwisscattle13.jpg',
#  'BrownSwisscattle130.jpg',
#  'BrownSwisscattle130_c.jpg',
#  'BrownSwisscattle132.jpg',
#  'BrownSwisscattle132_c.jpg',
#  'BrownSwisscattle133.jpg',
#  'BrownSwisscattle133_c.jpg',
#  'BrownSwisscattle134.jpg',
#  'BrownSwisscattle134_c.jpg',
#  'BrownSwisscattle135.jpg',
#  'BrownSwisscattle135_c.jpg',
#  'BrownSwisscattle136.jpg',
#  'BrownSwisscattle136_c.jpg',
#  'BrownSwisscattle137.jpg',
#  'BrownSwisscattle137_c.jpg',
#  'BrownSwisscattle138.jpg',
#  'BrownSwisscattle138_c.jpg',
#  'BrownSwisscattle139.jpg',
#  'BrownSwisscattle139_c.jpg',
#  'BrownSwisscattle13_c.jpg',
#  'BrownSwisscattle140.jpg',
#  'BrownSwisscattle140_c.jpg',
#  'BrownSwisscattle141.jpg',
#  'BrownSwisscattle141_c.jpg',
#  'BrownSwisscattle145.jpg',
#  'BrownSwisscattle145_c.jpg',
#  'BrownSwisscattle146.jpg',
#  'BrownSwisscattle146_c.jpg',
#  'BrownSwisscattle147.jpg',
#  'BrownSwisscattle147_c.jpg',
#  'BrownSwisscattle148.jpg',
#  'BrownSwisscattle148_c.jpg',
#  'BrownSwisscattle149.jpg',
#  'BrownSwisscattle149_c.jpg',
#  'BrownSwisscattle15.jpg',
#  'BrownSwisscattle15_c.jpg',
#  'BrownSwisscattle17.jpg',
#  'BrownSwisscattle17_c.jpg',
#  'BrownSwisscattle18.jpg',
#  'BrownSwisscattle18_c.jpg',
#  'BrownSwisscattle19.jpg',
#  'BrownSwisscattle19_c.jpg',
#  'BrownSwisscattle1_c.jpg',
#  'BrownSwisscattle2.jpg',
#  'BrownSwisscattle20.jpg',
#  'BrownSwisscattle20_c.jpg',
#  'BrownSwisscattle21.jpg',
#  'BrownSwisscattle21_c.jpg',
#  'BrownSwisscattle23.jpg',
#  'BrownSwisscattle23_c.jpg',
#  'BrownSwisscattle24.jpg',
#  'BrownSwisscattle24_c.jpg',
#  'BrownSwisscattle25.jpg',
#  'BrownSwisscattle25_c.jpg',
#  'BrownSwisscattle27.jpg',
#  'BrownSwisscattle27_c.jpg',
#  'BrownSwisscattle28.jpg',
#  'BrownSwisscattle28_c.jpg',
#  'BrownSwisscattle29.jpg',
#  'BrownSwisscattle29_c.jpg',
#  'BrownSwisscattle2_c.jpg',
#  'BrownSwisscattle3.jpg',
#  'BrownSwisscattle30.jpg',
#  'BrownSwisscattle30_c.jpg',
#  'BrownSwisscattle31.jpg',
#  'BrownSwisscattle31_c.jpg',
#  'BrownSwisscattle32.jpg',
#  'BrownSwisscattle32_c.jpg',
#  'BrownSwisscattle33.jpg',
#  'BrownSwisscattle33_c.jpg',
#  'BrownSwisscattle34.jpg',
#  'BrownSwisscattle34_c.jpg',
#  'BrownSwisscattle36.jpg',
#  'BrownSwisscattle36_c.jpg',
#  'BrownSwisscattle38.jpg',
#  'BrownSwisscattle38_c.jpg',
#  'BrownSwisscattle3_c.jpg',
#  'BrownSwisscattle4.jpg',
#  'BrownSwisscattle40.jpg',
#  'BrownSwisscattle40_c.jpg',
#  'BrownSwisscattle42.jpg',
#  'BrownSwisscattle42_c.jpg',
#  'BrownSwisscattle43.jpg',
#  'BrownSwisscattle43_c.jpg',
#  'BrownSwisscattle46.jpg',
#  'BrownSwisscattle46_c.jpg',
#  'BrownSwisscattle47.jpg',
#  'BrownSwisscattle47_c.jpg',
#  'BrownSwisscattle48.jpg',
#  'BrownSwisscattle48_c.jpg',
#  'BrownSwisscattle4_c.jpg',
#  'BrownSwisscattle5.jpg',
#  'BrownSwisscattle50.jpg',
#  'BrownSwisscattle50_c.jpg',
#  'BrownSwisscattle52.jpg',
#  'BrownSwisscattle52_c.jpg',
#  'BrownSwisscattle53.jpg',
#  'BrownSwisscattle53_c.jpg',
#  'BrownSwisscattle54.jpg',
#  'BrownSwisscattle54_c.jpg',
#  'BrownSwisscattle56.jpg',
#  'BrownSwisscattle56_c.jpg',
#  'BrownSwisscattle58.jpg',
#  'BrownSwisscattle58_c.jpg',
#  'BrownSwisscattle59.jpg',
#  'BrownSwisscattle59_c.jpg',
#  'BrownSwisscattle5_c.jpg',
#  'BrownSwisscattle6.jpg',
#  'BrownSwisscattle60.jpg',
#  'BrownSwisscattle60_c.jpg',
#  'BrownSwisscattle61.jpg',
#  'BrownSwisscattle61_c.jpg',
#  'BrownSwisscattle62.jpg',
#  'BrownSwisscattle62_c.jpg',
#  'BrownSwisscattle65.jpg',
#  'BrownSwisscattle65_c.jpg',
#  'BrownSwisscattle66.jpg',
#  'BrownSwisscattle66_c.jpg',
#  'BrownSwisscattle67.jpg',
#  'BrownSwisscattle67_c.jpg',
#  'BrownSwisscattle68.jpg',
#  'BrownSwisscattle68_c.jpg',
#  'BrownSwisscattle6_c.jpg',
#  'BrownSwisscattle70.jpg',
#  'BrownSwisscattle70_c.jpg',
#  'BrownSwisscattle71.jpg',
#  'BrownSwisscattle71_c.jpg',
#  'BrownSwisscattle72.jpg',
#  'BrownSwisscattle72_c.jpg',
#  'BrownSwisscattle74.jpg',
#  'BrownSwisscattle74_c.jpg',
#  'BrownSwisscattle75.jpg',
#  'BrownSwisscattle75_c.jpg',
#  'BrownSwisscattle76.jpg',
#  'BrownSwisscattle76_c.jpg',
#  'BrownSwisscattle77.jpg',
#  'BrownSwisscattle77_c.jpg',
#  'BrownSwisscattle78.jpg',
#  'BrownSwisscattle78_c.jpg',
#  'BrownSwisscattle79.jpg',
#  'BrownSwisscattle79_c.jpg',
#  'BrownSwisscattle8.jpg',
#  'BrownSwisscattle80.jpg',
#  'BrownSwisscattle80_c.jpg',
#  'BrownSwisscattle81.jpg',
#  'BrownSwisscattle81_c.jpg',
#  'BrownSwisscattle82.jpg',
#  'BrownSwisscattle82_c.jpg',
#  'BrownSwisscattle83.jpg',
#  'BrownSwisscattle83_c.jpg',
#  'BrownSwisscattle84.jpg',
#  'BrownSwisscattle84_c.jpg',
#  'BrownSwisscattle85.jpg',
#  'BrownSwisscattle85_c.jpg',
#  'BrownSwisscattle86.jpg',
#  'BrownSwisscattle86_c.jpg',
#  'BrownSwisscattle87.jpg',
#  'BrownSwisscattle87_c.jpg',
#  'BrownSwisscattle88.jpg',
#  'BrownSwisscattle88_c.jpg',
#  'BrownSwisscattle89.jpg',
#  'BrownSwisscattle89_c.jpg',
#  'BrownSwisscattle8_c.jpg',
#  'BrownSwisscattle9.jpg',
#  'BrownSwisscattle90.jpg',
#  'BrownSwisscattle90_c.jpg',
#  'BrownSwisscattle91.jpg',
#  'BrownSwisscattle91_c.jpg',
#  'BrownSwisscattle92.jpg',
#  'BrownSwisscattle92_c.jpg',
#  'BrownSwisscattle95.jpg',
#  'BrownSwisscattle95_c.jpg',
#  'BrownSwisscattle96.jpg',
#  'BrownSwisscattle96_c.jpg',
#  'BrownSwisscattle97.jpg',
#  'BrownSwisscattle97_c.jpg',
#  'BrownSwisscattle98.jpg',
#  'BrownSwisscattle98_c.jpg',
#  'BrownSwisscattle99.jpg',
#  'BrownSwisscattle99_c.jpg',
#  'BrownSwisscattle9_c.jpg',
#  'HolsteinFriesiancattle1.jpg',
#  'HolsteinFriesiancattle10.jpg',
#  'HolsteinFriesiancattle100.jpg',
#  'HolsteinFriesiancattle100_c.jpg',
#  'HolsteinFriesiancattle101.jpg',
#  'HolsteinFriesiancattle101_c.jpg',
#  'HolsteinFriesiancattle102.jpg',
#  'HolsteinFriesiancattle102_c.jpg',
#  'HolsteinFriesiancattle103.jpg',
#  'HolsteinFriesiancattle103_c.jpg',
#  'HolsteinFriesiancattle104.jpg',
#  'HolsteinFriesiancattle104_c.jpg',
#  'HolsteinFriesiancattle105.jpg',
#  'HolsteinFriesiancattle105_c.jpg',
#  'HolsteinFriesiancattle106.jpg',
#  'HolsteinFriesiancattle106_c.jpg',
#  'HolsteinFriesiancattle107.jpg',
#  'HolsteinFriesiancattle107_c.jpg',
#  'HolsteinFriesiancattle108.jpg',
#  'HolsteinFriesiancattle108_c.jpg',
#  'HolsteinFriesiancattle109.jpg',
#  'HolsteinFriesiancattle109_c.jpg',
#  'HolsteinFriesiancattle10_c.jpg',
#  'HolsteinFriesiancattle11.jpg',
#  'HolsteinFriesiancattle110.jpg',
#  'HolsteinFriesiancattle110_c.jpg',
#  'HolsteinFriesiancattle111.jpg',
#  'HolsteinFriesiancattle111_c.jpg',
#  'HolsteinFriesiancattle112.jpg',
#  'HolsteinFriesiancattle112_c.jpg',
#  'HolsteinFriesiancattle114.jpg',
#  'HolsteinFriesiancattle114_c.jpg',
#  'HolsteinFriesiancattle115.jpg',
#  'HolsteinFriesiancattle115_c.jpg',
#  'HolsteinFriesiancattle116.jpg',
#  'HolsteinFriesiancattle116_c.jpg',
#  'HolsteinFriesiancattle117.jpg',
#  'HolsteinFriesiancattle117_c.jpg',
#  'HolsteinFriesiancattle118.jpg',
#  'HolsteinFriesiancattle118_c.jpg',
#  'HolsteinFriesiancattle11_c.jpg',
#  'HolsteinFriesiancattle12.jpg',
#  'HolsteinFriesiancattle120.jpg',
#  'HolsteinFriesiancattle120_c.jpg',
#  'HolsteinFriesiancattle121.jpg',
#  'HolsteinFriesiancattle121_c.jpg',
#  'HolsteinFriesiancattle122.jpg',
#  'HolsteinFriesiancattle122_c.jpg',
#  'HolsteinFriesiancattle123.jpg',
#  'HolsteinFriesiancattle123_c.jpg',
#  'HolsteinFriesiancattle124.jpg',
#  'HolsteinFriesiancattle124_c.jpg',
#  'HolsteinFriesiancattle125.jpg',
#  'HolsteinFriesiancattle125_c.jpg',
#  'HolsteinFriesiancattle126.jpg',
#  'HolsteinFriesiancattle126_c.jpg',
#  'HolsteinFriesiancattle127.jpg',
#  'HolsteinFriesiancattle127_c.jpg',
#  'HolsteinFriesiancattle128.jpg',
#  'HolsteinFriesiancattle128_c.jpg',
#  'HolsteinFriesiancattle129.jpg',
#  'HolsteinFriesiancattle129_c.jpg',
#  'HolsteinFriesiancattle12_c.jpg',
#  'HolsteinFriesiancattle13.jpg',
#  'HolsteinFriesiancattle131.jpg',
#  'HolsteinFriesiancattle131_c.jpg',
#  'HolsteinFriesiancattle132.jpg',
#  'HolsteinFriesiancattle132_c.jpg',
#  'HolsteinFriesiancattle133.jpg',
#  'HolsteinFriesiancattle133_c.jpg',
#  'HolsteinFriesiancattle134.jpg',
#  'HolsteinFriesiancattle134_c.jpg',
#  'HolsteinFriesiancattle135.jpg',
#  'HolsteinFriesiancattle135_c.jpg',
#  'HolsteinFriesiancattle137.jpg',
#  'HolsteinFriesiancattle137_c.jpg',
#  'HolsteinFriesiancattle139.jpg',
#  'HolsteinFriesiancattle139_c.jpg',
#  'HolsteinFriesiancattle13_c.jpg',
#  'HolsteinFriesiancattle14.jpg',
#  'HolsteinFriesiancattle140.jpg',
#  'HolsteinFriesiancattle140_c.jpg',
#  'HolsteinFriesiancattle142.jpg',
#  'HolsteinFriesiancattle142_c.jpg',
#  'HolsteinFriesiancattle143.jpg',
#  'HolsteinFriesiancattle143_c.jpg',
#  'HolsteinFriesiancattle144.jpg',
#  'HolsteinFriesiancattle144_c.jpg',
#  'HolsteinFriesiancattle145.jpg',
#  'HolsteinFriesiancattle145_c.jpg',
#  'HolsteinFriesiancattle146.jpg',
#  'HolsteinFriesiancattle146_c.jpg',
#  'HolsteinFriesiancattle147.jpg',
#  'HolsteinFriesiancattle147_c.jpg',
#  'HolsteinFriesiancattle148.jpg',
#  'HolsteinFriesiancattle148_c.jpg',
#  'HolsteinFriesiancattle149.jpg',
#  'HolsteinFriesiancattle149_c.jpg',
#  'HolsteinFriesiancattle14_c.jpg',
#  'HolsteinFriesiancattle15.jpg',
#  'HolsteinFriesiancattle15_c.jpg',
#  'HolsteinFriesiancattle16.jpg',
#  'HolsteinFriesiancattle16_c.jpg',
#  'HolsteinFriesiancattle17.jpg',
#  'HolsteinFriesiancattle17_c.jpg',
#  'HolsteinFriesiancattle18.jpg',
#  'HolsteinFriesiancattle18_c.jpg',
#  'HolsteinFriesiancattle19.jpg',
#  'HolsteinFriesiancattle19_c.jpg',
#  'HolsteinFriesiancattle1_c.jpg',
#  'HolsteinFriesiancattle2.jpg',
#  'HolsteinFriesiancattle20.jpg',
#  'HolsteinFriesiancattle20_c.jpg',
#  'HolsteinFriesiancattle21.jpg',
#  'HolsteinFriesiancattle21_c.jpg',
#  'HolsteinFriesiancattle23.jpg',
#  'HolsteinFriesiancattle23_c.jpg',
#  'HolsteinFriesiancattle24.jpg',
#  'HolsteinFriesiancattle24_c.jpg',
#  'HolsteinFriesiancattle25.jpg',
#  'HolsteinFriesiancattle25_c.jpg',
#  'HolsteinFriesiancattle26.jpg',
#  'HolsteinFriesiancattle26_c.jpg',
#  'HolsteinFriesiancattle27.jpg',
#  'HolsteinFriesiancattle27_c.jpg',
#  'HolsteinFriesiancattle28.jpg',
#  'HolsteinFriesiancattle28_c.jpg',
#  'HolsteinFriesiancattle29.jpg',
#  'HolsteinFriesiancattle29_c.jpg',
#  'HolsteinFriesiancattle2_c.jpg',
#  'HolsteinFriesiancattle30.jpg',
#  'HolsteinFriesiancattle30_c.jpg',
#  'HolsteinFriesiancattle31.jpg',
#  'HolsteinFriesiancattle31_c.jpg',
#  'HolsteinFriesiancattle32.jpg',
#  'HolsteinFriesiancattle32_c.jpg',
#  'HolsteinFriesiancattle33.jpg',
#  'HolsteinFriesiancattle33_c.jpg',
#  'HolsteinFriesiancattle34.jpg',
#  'HolsteinFriesiancattle34_c.jpg',
#  'HolsteinFriesiancattle35.jpg',
#  'HolsteinFriesiancattle35_c.jpg',
#  'HolsteinFriesiancattle36.jpg',
#  'HolsteinFriesiancattle36_c.jpg',
#  'HolsteinFriesiancattle37.jpg',
#  'HolsteinFriesiancattle37_c.jpg',
#  'HolsteinFriesiancattle38.jpg',
#  'HolsteinFriesiancattle38_c.jpg',
#  'HolsteinFriesiancattle39.jpg',
#  'HolsteinFriesiancattle39_c.jpg',
#  'HolsteinFriesiancattle40.jpg',
#  'HolsteinFriesiancattle40_c.jpg',
#  'HolsteinFriesiancattle42.jpg',
#  'HolsteinFriesiancattle42_c.jpg',
#  'HolsteinFriesiancattle43.jpg',
#  'HolsteinFriesiancattle43_c.jpg',
#  'HolsteinFriesiancattle45.jpg',
#  'HolsteinFriesiancattle45_c.jpg',
#  'HolsteinFriesiancattle48.jpg',
#  'HolsteinFriesiancattle48_c.jpg',
#  'HolsteinFriesiancattle49.jpg',
#  'HolsteinFriesiancattle49_c.jpg',
#  'HolsteinFriesiancattle5.jpg',
#  'HolsteinFriesiancattle50.jpg',
#  'HolsteinFriesiancattle50_c.jpg',
#  'HolsteinFriesiancattle51.jpg',
#  'HolsteinFriesiancattle51_c.jpg',
#  'HolsteinFriesiancattle52.jpg',
#  'HolsteinFriesiancattle52_c.jpg',
#  'HolsteinFriesiancattle53.jpg',
#  'HolsteinFriesiancattle53_c.jpg',
#  'HolsteinFriesiancattle54.jpg',
#  'HolsteinFriesiancattle54_c.jpg',
#  'HolsteinFriesiancattle55.jpg',
#  'HolsteinFriesiancattle55_c.jpg',
#  'HolsteinFriesiancattle56.jpg',
#  'HolsteinFriesiancattle56_c.jpg',
#  'HolsteinFriesiancattle57.jpg',
#  'HolsteinFriesiancattle57_c.jpg',
#  'HolsteinFriesiancattle58.jpg',
#  'HolsteinFriesiancattle58_c.jpg',
#  'HolsteinFriesiancattle5_c.jpg',
#  'HolsteinFriesiancattle6.jpg',
#  'HolsteinFriesiancattle60.jpg',
#  'HolsteinFriesiancattle60_c.jpg',
#  'HolsteinFriesiancattle61.jpg',
#  'HolsteinFriesiancattle61_c.jpg',
#  'HolsteinFriesiancattle62.jpg',
#  'HolsteinFriesiancattle62_c.jpg',
#  'HolsteinFriesiancattle63.jpg',
#  'HolsteinFriesiancattle63_c.jpg',
#  'HolsteinFriesiancattle64.jpg',
#  'HolsteinFriesiancattle64_c.jpg',
#  'HolsteinFriesiancattle65.jpg',
#  'HolsteinFriesiancattle65_c.jpg',
#  'HolsteinFriesiancattle66.jpg',
#  'HolsteinFriesiancattle66_c.jpg',
#  'HolsteinFriesiancattle67.jpg',
#  'HolsteinFriesiancattle67_c.jpg',
#  'HolsteinFriesiancattle68.jpg',
#  'HolsteinFriesiancattle68_c.jpg',
#  'HolsteinFriesiancattle69.jpg',
#  'HolsteinFriesiancattle69_c.jpg',
#  'HolsteinFriesiancattle6_c.jpg',
#  'HolsteinFriesiancattle70.jpg',
#  'HolsteinFriesiancattle70_c.jpg',
#  'HolsteinFriesiancattle71.jpg',
#  'HolsteinFriesiancattle71_c.jpg',
#  'HolsteinFriesiancattle72.jpg',
#  'HolsteinFriesiancattle72_c.jpg',
#  'HolsteinFriesiancattle73.jpg',
#  'HolsteinFriesiancattle73_c.jpg',
#  'HolsteinFriesiancattle74.jpg',
#  'HolsteinFriesiancattle74_c.jpg',
#  'HolsteinFriesiancattle75.jpg',
#  'HolsteinFriesiancattle75_c.jpg',
#  'HolsteinFriesiancattle78.jpg',
#  'HolsteinFriesiancattle78_c.jpg',
#  'HolsteinFriesiancattle8.jpg',
#  'HolsteinFriesiancattle81.jpg',
#  'HolsteinFriesiancattle81_c.jpg',
#  'HolsteinFriesiancattle82.jpg',
#  'HolsteinFriesiancattle82_c.jpg',
#  'HolsteinFriesiancattle83.jpg',
#  'HolsteinFriesiancattle83_c.jpg',
#  'HolsteinFriesiancattle84.jpg',
#  'HolsteinFriesiancattle84_c.jpg',
#  'HolsteinFriesiancattle85.jpg',
#  'HolsteinFriesiancattle85_c.jpg',
#  'HolsteinFriesiancattle86.jpg',
#  'HolsteinFriesiancattle86_c.jpg',
#  'HolsteinFriesiancattle87.jpg',
#  'HolsteinFriesiancattle87_c.jpg',
#  'HolsteinFriesiancattle8_c.jpg',
#  'HolsteinFriesiancattle9.jpg',
#  'HolsteinFriesiancattle90.jpg',
#  'HolsteinFriesiancattle90_c.jpg',
#  'HolsteinFriesiancattle91.jpg',
#  'HolsteinFriesiancattle91_c.jpg',
#  'HolsteinFriesiancattle92.jpg',
#  'HolsteinFriesiancattle92_c.jpg',
#  'HolsteinFriesiancattle93.jpg',
#  'HolsteinFriesiancattle93_c.jpg',
#  'HolsteinFriesiancattle94.jpg',
#  'HolsteinFriesiancattle94_c.jpg',
#  'HolsteinFriesiancattle95.jpg',
#  'HolsteinFriesiancattle95_c.jpg',
#  'HolsteinFriesiancattle96.jpg',
#  'HolsteinFriesiancattle96_c.jpg',
#  'HolsteinFriesiancattle98.jpg',
#  'HolsteinFriesiancattle98_c.jpg',
#  'HolsteinFriesiancattle99.jpg',
#  'HolsteinFriesiancattle99_c.jpg',
#  'HolsteinFriesiancattle9_c.jpg',
#  'Jerseycattle0.jpg',
#  'Jerseycattle0_c.jpg',
#  'Jerseycattle1.jpg',
#  'Jerseycattle10.jpg',
#  'Jerseycattle100.jpg',
#  'Jerseycattle100_c.jpg',
#  'Jerseycattle101.jpg',
#  'Jerseycattle101_c.jpg',
#  'Jerseycattle103.jpg',
#  'Jerseycattle103_c.jpg',
#  'Jerseycattle104.jpg',
#  'Jerseycattle104_c.jpg',
#  'Jerseycattle105.jpg',
#  'Jerseycattle105_c.jpg',
#  'Jerseycattle106.jpg',
#  'Jerseycattle106_c.jpg',
#  'Jerseycattle107.jpg',
#  'Jerseycattle107_c.jpg',
#  'Jerseycattle108.jpg',
#  'Jerseycattle108_c.jpg',
#  'Jerseycattle109.jpg',
#  'Jerseycattle109_c.jpg',
#  'Jerseycattle10_c.jpg',
#  'Jerseycattle11.jpg',
#  'Jerseycattle110.jpg',
#  'Jerseycattle110_c.jpg',
#  'Jerseycattle111.jpg',
#  'Jerseycattle111_c.jpg',
#  'Jerseycattle112.jpg',
#  'Jerseycattle112_c.jpg',
#  'Jerseycattle113.jpg',
#  'Jerseycattle113_c.jpg',
#  'Jerseycattle115.jpg',
#  'Jerseycattle115_c.jpg',
#  'Jerseycattle116.jpg',
#  'Jerseycattle116_c.jpg',
#  'Jerseycattle118.jpg',
#  'Jerseycattle118_c.jpg',
#  'Jerseycattle119.jpg',
#  'Jerseycattle119_c.jpg',
#  'Jerseycattle11_c.jpg',
#  'Jerseycattle12.jpg',
#  'Jerseycattle120.jpg',
#  'Jerseycattle120_c.jpg',
#  'Jerseycattle121.jpg',
#  'Jerseycattle121_c.jpg',
#  'Jerseycattle122.jpg',
#  'Jerseycattle122_c.jpg',
#  'Jerseycattle123.jpg',
#  'Jerseycattle123_c.jpg',
#  'Jerseycattle124.jpg',
#  'Jerseycattle124_c.jpg',
#  'Jerseycattle125.jpg',
#  'Jerseycattle125_c.jpg',
#  'Jerseycattle126.jpg',
#  'Jerseycattle126_c.jpg',
#  'Jerseycattle127.jpg',
#  'Jerseycattle127_c.jpg',
#  'Jerseycattle128.jpg',
#  'Jerseycattle128_c.jpg',
#  'Jerseycattle129.jpg',
#  'Jerseycattle129_c.jpg',
#  'Jerseycattle12_c.jpg',
#  'Jerseycattle13.jpg',
#  'Jerseycattle130.jpg',
#  'Jerseycattle130_c.jpg',
#  'Jerseycattle131.jpg',
#  'Jerseycattle131_c.jpg',
#  'Jerseycattle132.jpg',
#  'Jerseycattle132_c.jpg',
#  'Jerseycattle133.jpg',
#  'Jerseycattle133_c.jpg',
#  'Jerseycattle134.jpg',
#  'Jerseycattle134_c.jpg',
#  'Jerseycattle135.jpg',
#  'Jerseycattle135_c.jpg',
#  'Jerseycattle136.jpg',
#  'Jerseycattle136_c.jpg',
#  'Jerseycattle137.jpg',
#  'Jerseycattle137_c.jpg',
#  'Jerseycattle138.jpg',
#  'Jerseycattle138_c.jpg',
#  'Jerseycattle13_c.jpg',
#  'Jerseycattle14.jpg',
#  'Jerseycattle141.jpg',
#  'Jerseycattle141_c.jpg',
#  'Jerseycattle142.jpg',
#  'Jerseycattle142_c.jpg',
#  'Jerseycattle143.jpg',
#  'Jerseycattle143_c.jpg',
#  'Jerseycattle144.jpg',
#  'Jerseycattle144_c.jpg',
#  'Jerseycattle146.jpg',
#  'Jerseycattle146_c.jpg',
#  'Jerseycattle147.jpg',
#  'Jerseycattle147_c.jpg',
#  'Jerseycattle148.jpg',
#  'Jerseycattle148_c.jpg',
#  'Jerseycattle149.jpg',
#  'Jerseycattle149_c.jpg',
#  'Jerseycattle14_c.jpg',
#  'Jerseycattle15.jpg',
#  'Jerseycattle15_c.jpg',
#  'Jerseycattle17.jpg',
#  'Jerseycattle17_c.jpg',
#  'Jerseycattle19.jpg',
#  'Jerseycattle19_c.jpg',
#  'Jerseycattle1_c.jpg',
#  'Jerseycattle2.jpg',
#  'Jerseycattle20.jpg',
#  'Jerseycattle20_c.jpg',
#  'Jerseycattle21.jpg',
#  'Jerseycattle21_c.jpg',
#  'Jerseycattle22.jpg',
#  'Jerseycattle22_c.jpg',
#  'Jerseycattle23.jpg',
#  'Jerseycattle23_c.jpg',
#  'Jerseycattle24.jpg',
#  'Jerseycattle24_c.jpg',
#  'Jerseycattle25.jpg',
#  'Jerseycattle25_c.jpg',
#  'Jerseycattle26.jpg',
#  'Jerseycattle26_c.jpg',
#  'Jerseycattle27.jpg',
#  'Jerseycattle27_c.jpg',
#  'Jerseycattle28.jpg',
#  'Jerseycattle28_c.jpg',
#  'Jerseycattle2_c.jpg',
#  'Jerseycattle3.jpg',
#  'Jerseycattle30.jpg',
#  'Jerseycattle30_c.jpg',
#  'Jerseycattle31.jpg',
#  'Jerseycattle31_c.jpg',
#  'Jerseycattle32.jpg',
#  'Jerseycattle32_c.jpg',
#  'Jerseycattle33.jpg',
#  'Jerseycattle33_c.jpg',
#  'Jerseycattle34.jpg',
#  'Jerseycattle34_c.jpg',
#  'Jerseycattle35.jpg',
#  'Jerseycattle35_c.jpg',
#  'Jerseycattle38.jpg',
#  'Jerseycattle38_c.jpg',
#  'Jerseycattle3_c.jpg',
#  'Jerseycattle4.jpg',
#  'Jerseycattle40.jpg',
#  'Jerseycattle40_c.jpg',
#  'Jerseycattle43.jpg',
#  'Jerseycattle43_c.jpg',
#  'Jerseycattle45.jpg',
#  'Jerseycattle45_c.jpg',
#  'Jerseycattle46.jpg',
#  'Jerseycattle46_c.jpg',
#  'Jerseycattle47.jpg',
#  'Jerseycattle47_c.jpg',
#  'Jerseycattle48.jpg',
#  'Jerseycattle48_c.jpg',
#  'Jerseycattle49.jpg',
#  'Jerseycattle49_c.jpg',
#  'Jerseycattle4_c.jpg',
#  'Jerseycattle5.jpg',
#  'Jerseycattle50.jpg',
#  'Jerseycattle50_c.jpg',
#  'Jerseycattle52.jpg',
#  'Jerseycattle52_c.jpg',
#  'Jerseycattle54.jpg',
#  'Jerseycattle54_c.jpg',
#  'Jerseycattle55.jpg',
#  'Jerseycattle55_c.jpg',
#  'Jerseycattle56.jpg',
#  'Jerseycattle56_c.jpg',
#  'Jerseycattle57.jpg',
#  'Jerseycattle57_c.jpg',
#  'Jerseycattle58.jpg',
#  'Jerseycattle58_c.jpg',
#  'Jerseycattle59.jpg',
#  'Jerseycattle59_c.jpg',
#  'Jerseycattle5_c.jpg',
#  'Jerseycattle60.jpg',
#  'Jerseycattle60_c.jpg',
#  'Jerseycattle61.jpg',
#  'Jerseycattle61_c.jpg',
#  'Jerseycattle62.jpg',
#  'Jerseycattle62_c.jpg',
#  'Jerseycattle64.jpg',
#  'Jerseycattle64_c.jpg',
#  'Jerseycattle65.jpg',
#  'Jerseycattle65_c.jpg',
#  'Jerseycattle66.jpg',
#  'Jerseycattle66_c.jpg',
#  'Jerseycattle67.jpg',
#  'Jerseycattle67_c.jpg',
#  'Jerseycattle68.jpg',
#  'Jerseycattle68_c.jpg',
#  'Jerseycattle7.jpg',
#  'Jerseycattle70.jpg',
#  'Jerseycattle70_c.jpg',
#  'Jerseycattle71.jpg',
#  'Jerseycattle71_c.jpg',
#  'Jerseycattle72.jpg',
#  'Jerseycattle72_c.jpg',
#  'Jerseycattle73.jpg',
#  'Jerseycattle73_c.jpg',
#  'Jerseycattle75.jpg',
#  'Jerseycattle75_c.jpg',
#  'Jerseycattle76.jpg',
#  'Jerseycattle76_c.jpg',
#  'Jerseycattle77.jpg',
#  'Jerseycattle77_c.jpg',
#  'Jerseycattle78.jpg',
#  'Jerseycattle78_c.jpg',
#  'Jerseycattle79.jpg',
#  'Jerseycattle79_c.jpg',
#  'Jerseycattle7_c.jpg',
#  'Jerseycattle8.jpg',
#  'Jerseycattle80.jpg',
#  'Jerseycattle80_c.jpg',
#  'Jerseycattle81.jpg',
#  'Jerseycattle81_c.jpg',
#  'Jerseycattle83.jpg',
#  'Jerseycattle83_c.jpg',
#  'Jerseycattle84.jpg',
#  'Jerseycattle84_c.jpg',
#  'Jerseycattle85.jpg',
#  'Jerseycattle85_c.jpg',
#  'Jerseycattle86.jpg',
#  'Jerseycattle86_c.jpg',
#  'Jerseycattle87.jpg',
#  'Jerseycattle87_c.jpg',
#  'Jerseycattle88.jpg',
#  'Jerseycattle88_c.jpg',
#  'Jerseycattle89.jpg',
#  'Jerseycattle89_c.jpg',
#  'Jerseycattle8_c.jpg',
#  'Jerseycattle90.jpg',
#  'Jerseycattle90_c.jpg',
#  'Jerseycattle92.jpg',
#  'Jerseycattle92_c.jpg',
#  'Jerseycattle93.jpg',
#  'Jerseycattle93_c.jpg',
#  'Jerseycattle94.jpg',
#  'Jerseycattle94_c.jpg',
#  'Jerseycattle95.jpg',
#  'Jerseycattle95_c.jpg',
#  'Jerseycattle96.jpg',
#  'Jerseycattle96_c.jpg',
#  'Jerseycattle97.jpg',
#  'Jerseycattle97_c.jpg',
#  ...]

# %%
class Depthwise_Conv(nn.Module):
    def __init__(self, in_fts, stride=(1, 1)):
        super(Depthwise_Conv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_fts, in_fts, kernel_size=(3, 3), stride=stride, padding=(1, 1), groups=in_fts),
            nn.BatchNorm2d(in_fts),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        # print("Depthwise conv: ")
        # print("shape of x: ", x.shape )
        x = self.conv(x)
        return x


class Pointwise_Conv(nn.Module):
    def __init__(self, in_fts, out_fts):
        super(Pointwise_Conv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_fts, out_fts, kernel_size=(1, 1)),
            nn.BatchNorm2d(out_fts),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        # print("pointwise conv: ")
        # print("shape of x: ", x.shape )
        x = self.conv(x)
        return x


class Depthwise_Separable_Conv(nn.Module):
    def __init__(self, in_fts, out_fts, stride=(1, 1)):
        super(Depthwise_Separable_Conv, self).__init__()
        self.dw = Depthwise_Conv(in_fts=in_fts, stride=stride)
        self.pw = Pointwise_Conv(in_fts=in_fts, out_fts=out_fts)

    def forward(self, x):
        # print("Depthwise separable conv: ")
        # print("shape of x: ", x.shape )
        x = self.pw(self.dw(x))
        return x


class MyMobileNet_v1(nn.Module):
    def __init__(self, in_fts=3, num_filter=32, num_classes=1000):
        super(MyMobileNet_v1, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(in_fts, num_filter, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1)),
            nn.BatchNorm2d(num_filter),
            nn.ReLU(inplace=True)
        )

        self.in_fts = num_filter

        # if type of sublist is list --> means make stride=(2,2)
        # also check for length of sublist
        # if length = 1 --> means stride=(2,2)
        # if length = 2 --> means (num_times, num_filter)
        self.nlayer_filter = [
            num_filter * 2,  # no list() type --> default stride=(1,1)
            [num_filter * pow(2, 2)],  # list() type and length is 1 --> means put stride=(2,2)
            num_filter * pow(2, 2),
            [num_filter * pow(2, 3)],
            num_filter * pow(2, 3),
            [num_filter * pow(2, 4)],
            # list() type --> check length for this list = 2 --> means (n_times, num_filter)
            [5, num_filter * pow(2, 4)],
            [num_filter * pow(2, 5)],
            num_filter * pow(2, 5)
        ]

        self.DSC = self.layer_construct()

        self.avgpool = nn.AdaptiveAvgPool2d(output_size=(1, 1))
        self.fc = nn.Sequential(
            nn.Linear(1024, num_classes),
            nn.Softmax()
        )

    def forward(self, x):
        N = x.shape[0]
        # print("Mymobilenet: ")
        # print("shape of x: ",x.shape)
        x = self.conv(x)
        # print("shape of x after conv: ",x.shape)
        x = self.DSC(x)
        # print("shape of x after DSC: ",x.shape)
        x = self.avgpool(x)
        # print("shape of x after average pool: ",x.shape)
        x = x.reshape(N, -1)
        # print("shape of x after reshape: ",x.shape)
        x = self.fc(x)
        # print("shape of x after fully connecting: ",x.shape)
        return x

    def layer_construct(self):
        block = OrderedDict()
        index = 1
        for l in self.nlayer_filter:
            if type(l) == list:
                if len(l) == 2:  # (num_times, out_channel)
                    for _ in range(l[0]):
                        block[str(index)] = Depthwise_Separable_Conv(self.in_fts, l[1])
                        index += 1
                else:  # stride(2,2)
                    block[str(index)] = Depthwise_Separable_Conv(self.in_fts, l[0], stride=(2, 2))
                    self.in_fts = l[0]
                    index += 1
            else:
                block[str(index)] = Depthwise_Separable_Conv(self.in_fts, l)
                self.in_fts = l
                index += 1

        return nn.Sequential(block)

# %%
512*4*4,128/pow(2,5)
# Out:
# (8192, 4.0)

# %%
num_classes = len(img_custom.p)
num_epochs = 1
batch_size = 16
learning_rate = 0.005

model = MyMobileNet_v1(num_classes=num_classes)


# Loss and optimizer
# criterion = nn.CrossEntropyLoss()
# optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay = 0.005, momentum = 0.9)  


# Train the model
total_step = len(train_dataloader)

# %%
from torchview import draw_graph

# model = testInceptionBlock()

architecture = 'mobilenet'
model_graph = draw_graph(model, input_size=(64,3,224,224), graph_dir ='TB' , roll=True, expand_nested=True, graph_name=f'self_{architecture}',save_graph=True,filename=f'self_{architecture}')
model_graph.visual_graph
# Out:
# /home/groupe/vs_code/jupyter/env/lib/python3.11/site-packages/torch/overrides.py:1647: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   result = torch_func_method(public_api, types, args, kwargs)

# %%
from torchview import draw_graph

# model = testInceptionBlock()

architecture = 'mobilenet'
model_graph = draw_graph(model, input_size=(64,3,224,224), graph_dir ='TB' , roll=True, expand_nested=True, graph_name=f'self_{architecture}',save_graph=True,filename=f'self_{architecture}')
# model_graph.visual_graph
# Out:
# Mymobilenet:
# shape of x:  torch.Size([64, 3, 224, 224])
# shape of x after conv:  torch.Size([64, 32, 112, 112])
# Depthwise separable conv:
# shape of x:  torch.Size([64, 32, 112, 112])
# Depthwise conv:
# shape of x:  torch.Size([64, 32, 112, 112])
# pointwise conv:
# shape of x:  torch.Size([64, 32, 112, 112])
# Depthwise separable conv:
# shape of x:  torch.Size([64, 64, 112, 112])
# Depthwise conv:
# shape of x:  torch.Size([64, 64, 112, 112])
# pointwise conv:
# shape of x:  torch.Size([64, 64, 56, 56])
# Depthwise separable conv:
# shape of x:  torch.Size([64, 128, 56, 56])
# Depthwise conv:
# shape of x:  torch.Size([64, 128, 56, 56])
# pointwise conv:
# shape of x:  torch.Size([64, 128, 56, 56])
# Depthwise separable conv:
# shape of x:  torch.Size([64, 128, 56, 56])
# Depthwise conv:
# shape of x:  torch.Size([64, 128, 56, 56])
# pointwise conv:
# shape of x:  torch.Size([64, 128, 28, 28])
# Depthwise separable conv:
# shape of x:  torch.Size([64, 256, 28, 28])
# Depthwise conv:
# shape of x:  torch.Size([64, 256, 28, 28])
# pointwise conv:
# shape of x:  torch.Size([64, 256, 28, 28])
# Depthwise separable conv:
# shape of x:  torch.Size([64, 256, 28, 28])
# Depthwise conv:
# shape of x:  torch.Size([64, 256, 28, 28])
# pointwise conv:
# shape of x:  torch.Size([64, 256, 14, 14])
# Depthwise separable conv:
# shape of x:  torch.Size([64, 512, 14, 14])
# Depthwise conv:
# shape of x:  torch.Size([64, 512, 14, 14])
# pointwise conv:
# shape of x:  torch.Size([64, 512, 14, 14])
# Depthwise separable conv:
# shape of x:  torch.Size([64, 512, 14, 14])
# Depthwise conv:
# shape of x:  torch.Size([64, 512, 14, 14])
# pointwise conv:
# shape of x:  torch.Size([64, 512, 14, 14])
# Depthwise separable conv:
# shape of x:  torch.Size([64, 512, 14, 14])
# Depthwise conv:
# shape of x:  torch.Size([64, 512, 14, 14])
# pointwise conv:
# shape of x:  torch.Size([64, 512, 14, 14])
# Depthwise separable conv:
# shape of x:  torch.Size([64, 512, 14, 14])
# Depthwise conv:
# shape of x:  torch.Size([64, 512, 14, 14])
# pointwise conv:
# shape of x:  torch.Size([64, 512, 14, 14])
# Depthwise separable conv:
# shape of x:  torch.Size([64, 512, 14, 14])
# Depthwise conv:
# shape of x:  torch.Size([64, 512, 14, 14])
# pointwise conv:
# shape of x:  torch.Size([64, 512, 14, 14])
# Depthwise separable conv:
# shape of x:  torch.Size([64, 512, 14, 14])
# Depthwise conv:
# shape of x:  torch.Size([64, 512, 14, 14])
# pointwise conv:
# shape of x:  torch.Size([64, 512, 7, 7])
# Depthwise separable conv:
# shape of x:  torch.Size([64, 1024, 7, 7])
# Depthwise conv:
# shape of x:  torch.Size([64, 1024, 7, 7])
# pointwise conv:
# shape of x:  torch.Size([64, 1024, 7, 7])
# shape of x after DSC:  torch.Size([64, 1024, 7, 7])
# shape of x after average pool:  torch.Size([64, 1024, 1, 1])
# shape of x after reshape:  torch.Size([64, 1024])
# shape of x after fully connecting:  torch.Size([64, 5])
# /home/groupe/vs_code/jupyter/env/lib/python3.11/site-packages/torch/overrides.py:1647: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   result = torch_func_method(public_api, types, args, kwargs)

# %%
total_step
# Out:
# 16

# %%
from tqdm.auto import tqdm
from timeit import default_timer as timer

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(
    params = model.parameters(),
    lr = 0.1
)

# %%
torch.manual_seed(42)
train_start_time = timer()

epochs = 3

for epoch in tqdm(range(epochs)):
    print(f"Epoch: {epoch}\n")
    train_loss = 0
    
    for batch, (X,y) in enumerate(train_dataloader):
        print(batch,X.shape,y.shape)
        model.train()

        y_pred = model(X)
        loss = loss_fn(y_pred, y)
        train_loss += loss

        optimizer.zero_grad()

        loss.backward()

        optimizer.step()
        
        del X,y
        
#         if batch == 15:
#             break

#         if batch % 10 == 0:
#             print(f"Batches {batch*len(X)}/{len(train_dataloader.dataset)} samples finished.")

    train_loss /= len(train_dataloader)

    test_loss, test_acc = 0,0

    model.eval()

    with torch.inference_mode():
        for X_test, y_test in test_dataloader:
            test_pred = model(X_test)
            test_loss += loss_fn(test_pred, y_test)
            # test_acc += accuracy_fn(y_true=y_test, y_pred=test_pred.argmax(dim=1))

        test_loss /= len(test_dataloader)
        # test_acc /= len(test_dataloader)

    print(f"\nTrain Loss: {train_loss:.4f} Test loss: {test_loss:.4f}")


train_end_time = timer()

print(f"Total time = {train_end_time - train_start_time}")
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch: 0
#
# 0 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 1 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 2 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 3 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 4 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 5 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 6 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 7 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 8 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 9 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 10 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 11 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 12 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 13 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 14 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 15 torch.Size([6, 3, 128, 128]) torch.Size([6])
#
# Train Loss: 1.4784 Test loss: 1.6294
# Epoch: 1
#
# 0 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 1 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 2 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 3 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 4 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 5 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 6 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 7 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 8 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 9 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 10 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 11 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 12 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 13 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 14 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 15 torch.Size([6, 3, 128, 128]) torch.Size([6])
#
# Train Loss: 1.4747 Test loss: 1.7034
# Epoch: 2
#
# 0 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 1 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 2 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 3 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 4 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 5 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 6 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 7 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 8 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 9 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 10 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 11 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 12 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 13 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 14 torch.Size([64, 3, 128, 128]) torch.Size([64])
# 15 torch.Size([6, 3, 128, 128]) torch.Size([6])
#
# Train Loss: 1.4673 Test loss: 1.6336
# Total time = 125.375194137996

# %%
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_dataloader:
#         images = images.to(device)
#         labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        del images, labels, outputs
        print(correct,total)

    print('Accuracy of the network on the {} test images: {} %'.format(10000, 100 * correct / total))
# Out:
# 11 64
# 28 128
# 46 192
# 58 242
# Accuracy of the network on the 10000 test images: 23.96694214876033 %

# %%
train_features[0].shape
# Out:
# torch.Size([3, 128, 128])

# %%
train_features, train_labels = next(iter(train_dataloader))
# print(f"Feature batch shape: {train_features.size()}")
# print(f"Labels batch shape: {train_labels.size()}")
# print(f"Labels batch shape: {train_labels.size()}")
img = train_features[2].squeeze()
label = train_labels[2]
_,label_pred = torch.max(model(train_features[0].unsqueeze(dim=0)),1)
print("Predicted: ",img_custom.p[label_pred],"\nActual: ",img_custom.p[label])
plt.imshow(img.permute(1,2,0), cmap="gray")
plt.show()
print(f"Label: {label}")
# Out:
# Predicted:  Holstein Friesian cattle
# Actual:  Brown Swiss cattle
# Label: 1
